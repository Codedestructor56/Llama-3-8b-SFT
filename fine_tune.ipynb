# %%
import torch
print(torch.__version__)
# Out:
# 2.2.2+cu121

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
# !pip install -U transformers datasets accelerate peft trl bitsandbytes wandb
# Out:
# 2413.13s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: transformers in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (4.39.3)
# Collecting transformers
#   Downloading transformers-4.40.0-py3-none-any.whl.metadata (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting datasets
#   Downloading datasets-2.19.0-py3-none-any.whl.metadata (19 kB)
# Collecting accelerate
#   Downloading accelerate-0.29.3-py3-none-any.whl.metadata (18 kB)
# Collecting peft
#   Downloading peft-0.10.0-py3-none-any.whl.metadata (13 kB)
# Collecting trl
#   Downloading trl-0.8.5-py3-none-any.whl.metadata (11 kB)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.43.1-py3-none-manylinux_2_24_x86_64.whl.metadata (2.2 kB)
# Collecting wandb
#   Downloading wandb-0.16.6-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: filelock in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from transformers) (3.13.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.20,>=0.19 (from transformers)
#   Downloading tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from transformers) (4.66.2)
# Collecting pyarrow>=12.0.0 (from datasets)
#   Downloading pyarrow-15.0.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from datasets) (2.2.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets) (2024.3.1)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.9.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: psutil in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: torch>=1.10.0 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from accelerate) (2.2.2)
# Collecting tyro>=0.5.11 (from trl)
#   Downloading tyro-0.8.3-py3-none-any.whl.metadata (7.9 kB)
# Collecting Click!=8.0.0,>=7.1 (from wandb)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.45.0-py2.py3-none-any.whl.metadata (9.9 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Requirement already satisfied: setuptools in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from wandb) (65.5.0)
# Collecting appdirs>=1.4.3 (from wandb)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting protobuf!=4.21.0,<5,>=3.19.0 (from wandb)
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: six>=1.4.0 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp->datasets)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->datasets)
#   Downloading yarl-1.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: sympy in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.4.127)
# Collecting docstring-parser>=0.14.1 (from tyro>=0.5.11->trl)
#   Downloading docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Collecting rich>=11.1.0 (from tyro>=0.5.11->trl)
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl)
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from pandas->datasets) (2024.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=11.1.0->tyro>=0.5.11->trl)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/richardM/pytorch-dir/env/lib/python3.11/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading transformers-4.40.0-py3-none-any.whl (9.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 2.0 MB/s eta 0:00:0000:0100:01
# Downloading datasets-2.19.0-py3-none-any.whl (542 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading accelerate-0.29.3-py3-none-any.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 3.3 MB/s eta 0:00:00a 0:00:01
# Downloading peft-0.10.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.1/199.1 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Downloading trl-0.8.5-py3-none-any.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.1/245.1 kB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading bitsandbytes-0.43.1-py3-none-manylinux_2_24_x86_64.whl (119.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 1.2 MB/s eta 0:00:0000:0100:03m
# Downloading wandb-0.16.6-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 1.7 MB/s eta 0:00:0000:0100:010m
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 3.6 MB/s eta 0:00:00
# Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Downloading aiohttp-3.9.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 3.4 MB/s eta 0:00:0000:0100:01
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 2.8 MB/s eta 0:00:00a 0:00:01
# Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Downloading pyarrow-15.0.2-cp311-cp311-manylinux_2_28_x86_64.whl (38.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 1.8 MB/s eta 0:00:0000:0100:01
# Downloading sentry_sdk-1.45.0-py2.py3-none-any.whl (267 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Downloading tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 1.0 MB/s eta 0:00:0000:0100:010m
# Downloading tyro-0.8.3-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.0/102.0 kB 1.3 MB/s eta 0:00:00 0:00:01
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 846.5 kB/s eta 0:00:00a 0:00:01
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading setproctitle-1.3.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Downloading xxhash-3.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 1.1 MB/s eta 0:00:00 0:00:01
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 3.1 MB/s eta 0:00:00
# Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Downloading frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (272 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.3/272.3 kB 8.4 MB/s eta 0:00:00
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.2 MB/s eta 0:00:00
# Downloading multidict-6.0.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.7/128.7 kB 2.4 MB/s eta 0:00:00a 0:00:01
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Downloading yarl-1.9.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (328 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.1/328.1 kB 750.4 kB/s eta 0:00:00a 0:00:01
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 2.5 MB/s eta 0:00:00a 0:00:01
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: appdirs, xxhash, smmap, shtab, setproctitle, sentry-sdk, pyarrow-hotfix, pyarrow, protobuf, multidict, mdurl, frozenlist, docstring-parser, docker-pycreds, dill, Click, attrs, yarl, multiprocess, markdown-it-py, gitdb, aiosignal, tokenizers, rich, GitPython, aiohttp, wandb, tyro, transformers, bitsandbytes, accelerate, peft, datasets, trl
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.15.2
#     Uninstalling tokenizers-0.15.2:
#       Successfully uninstalled tokenizers-0.15.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.39.3
#     Uninstalling transformers-4.39.3:
#       Successfully uninstalled transformers-4.39.3
# Successfully installed Click-8.1.7 GitPython-3.1.43 accelerate-0.29.3 aiohttp-3.9.5 aiosignal-1.3.1 appdirs-1.4.4 attrs-23.2.0 bitsandbytes-0.43.1 datasets-2.19.0 dill-0.3.8 docker-pycreds-0.4.0 docstring-parser-0.16 frozenlist-1.4.1 gitdb-4.0.11 markdown-it-py-3.0.0 mdurl-0.1.2 multidict-6.0.5 multiprocess-0.70.16 peft-0.10.0 protobuf-4.25.3 pyarrow-15.0.2 pyarrow-hotfix-0.6 rich-13.7.1 sentry-sdk-1.45.0 setproctitle-1.3.3 shtab-1.7.1 smmap-5.0.1 tokenizers-0.19.1 transformers-4.40.0 trl-0.8.5 tyro-0.8.3 wandb-0.16.6 xxhash-3.4.1 yarl-1.9.4

# %%
import os
import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel
from trl import SFTTrainer

# %%
base_model = "meta-llama/Meta-Llama-3-8B"
new_model = "DPOCodeLLama3-8B"
tokenizer = AutoTokenizer.from_pretrained(base_model)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/pytorch-dir/env/lib/python3.11/site-packages/huggingface_hub/utils/_errors.py:304, in hf_raise_for_status(response, endpoint_name)
#     303 try:
# --> 304     response.raise_for_status()
#     305 except HTTPError as e:
#
# File ~/pytorch-dir/env/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/meta-llama/Meta-Llama-3-8B/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# File ~/pytorch-dir/env/lib/python3.11/site-packages/transformers/utils/hub.py:398, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     396 try:
#     397     # Load from URL or cache if already cached
# --> 398     resolved_file = hf_hub_download(
#     399         path_or_repo_id,
#     400         filename,
#     401         subfolder=None if len(subfolder) == 0 else subfolder,
#     402         repo_type=repo_type,
#     403         revision=revision,
#     404         cache_dir=cache_dir,
#     405         user_agent=user_agent,
#     406         force_download=force_download,
#     407         proxies=proxies,
#     408         resume_download=resume_download,
#     409         token=token,
#     410         local_files_only=local_files_only,
#     411     )
#     412 except GatedRepoError as e:
#
# File ~/pytorch-dir/env/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:119, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     117     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 119 return fn(*args, **kwargs)
#
# File ~/pytorch-dir/env/lib/python3.11/site-packages/huggingface_hub/file_download.py:1403, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, headers, legacy_cache_layout, endpoint)
#    1401 elif isinstance(head_call_error, RepositoryNotFoundError) or isinstance(head_call_error, GatedRepoError):
#    1402     # Repo not found or gated => let's raise the actual error
# -> 1403     raise head_call_error
#    1404 else:
#    1405     # Otherwise: most likely a connection issue or Hub downtime => let's warn the user
#
# File ~/pytorch-dir/env/lib/python3.11/site-packages/huggingface_hub/file_download.py:1261, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, headers, legacy_cache_layout, endpoint)
#    1260 try:
# -> 1261     metadata = get_hf_file_metadata(
#    1262         url=url,
#    1263         token=token,
#    1264         proxies=proxies,
#    1265         timeout=etag_timeout,
#    1266         library_name=library_name,
#    1267         library_version=library_version,
#    1268         user_agent=user_agent,
#    1269     )
#    1270 except EntryNotFoundError as http_error:
#    1271     # Cache the non-existence of the file and raise
#
# File ~/pytorch-dir/env/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:119, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     117     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 119 return fn(*args, **kwargs)
#
# File ~/pytorch-dir/env/lib/python3.11/site-packages/huggingface_hub/file_download.py:1674, in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers)
#    1673 # Retrieve metadata
# -> 1674 r = _request_wrapper(
#    1675     method="HEAD",
#    1676     url=url,
#    1677     headers=headers,
#    1678     allow_redirects=False,
#    1679     follow_relative_redirects=True,
#    1680     proxies=proxies,
#    1681     timeout=timeout,
#    1682 )
#    1683 hf_raise_for_status(r)
#
# File ~/pytorch-dir/env/lib/python3.11/site-packages/huggingface_hub/file_download.py:369, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     368 if follow_relative_redirects:
# --> 369     response = _request_wrapper(
#     370         method=method,
#     371         url=url,
#     372         follow_relative_redirects=False,
#     373         **params,
#     374     )
#     376     # If redirection, we redirect only relative paths.
#     377     # This is useful in case of a renamed repository.
#
# File ~/pytorch-dir/env/lib/python3.11/site-packages/huggingface_hub/file_download.py:393, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     392 response = get_session().request(method=method, url=url, **params)
# --> 393 hf_raise_for_status(response)
#     394 return response
#
# File ~/pytorch-dir/env/lib/python3.11/site-packages/huggingface_hub/utils/_errors.py:321, in hf_raise_for_status(response, endpoint_name)
#     318     message = (
#     319         f"{response.status_code} Client Error." + "\n\n" + f"Cannot access gated repo for url {response.url}."
#     320     )
# --> 321     raise GatedRepoError(message, response) from e
#     323 elif error_message == "Access to this resource is disabled.":
#
# GatedRepoError: 401 Client Error. (Request ID: Root=1-66233314-6a220e0060cf264a547d9b4d;2fbf860f-0269-4320-bdb8-2623699eb74b)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Meta-Llama-3-8B/resolve/main/config.json.
# Repo model meta-llama/Meta-Llama-3-8B is gated. You must be authenticated to access it.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 3
#       1 base_model = "meta-llama/Meta-Llama-3-8B"
#       2 new_model = "DPOCodeLLama3-8B"
# ----> 3 tokenizer = AutoTokenizer.from_pretrained(base_model)
#
# File ~/pytorch-dir/env/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:819, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     817 if config_tokenizer_class is None:
#     818     if not isinstance(config, PretrainedConfig):
# --> 819         config = AutoConfig.from_pretrained(
#     820             pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     821         )
#     822     config_tokenizer_class = config.tokenizer_class
#     823     if hasattr(config, "auto_map") and "AutoTokenizer" in config.auto_map:
#
# File ~/pytorch-dir/env/lib/python3.11/site-packages/transformers/models/auto/configuration_auto.py:928, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     925 trust_remote_code = kwargs.pop("trust_remote_code", None)
#     926 code_revision = kwargs.pop("code_revision", None)
# --> 928 config_dict, unused_kwargs = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     929 has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#     930 has_local_code = "model_type" in config_dict and config_dict["model_type"] in CONFIG_MAPPING
#
# File ~/pytorch-dir/env/lib/python3.11/site-packages/transformers/configuration_utils.py:631, in PretrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     629 original_kwargs = copy.deepcopy(kwargs)
#     630 # Get config dict associated with the base config file
# --> 631 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     632 if "_commit_hash" in config_dict:
#     633     original_kwargs["_commit_hash"] = config_dict["_commit_hash"]
#
# File ~/pytorch-dir/env/lib/python3.11/site-packages/transformers/configuration_utils.py:686, in PretrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     682 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME)
#     684 try:
#     685     # Load from local folder or from cache or download from model Hub and cache
# --> 686     resolved_config_file = cached_file(
#     687         pretrained_model_name_or_path,
#     688         configuration_file,
#     689         cache_dir=cache_dir,
#     690         force_download=force_download,
#     691         proxies=proxies,
#     692         resume_download=resume_download,
#     693         local_files_only=local_files_only,
#     694         token=token,
#     695         user_agent=user_agent,
#     696         revision=revision,
#     697         subfolder=subfolder,
#     698         _commit_hash=commit_hash,
#     699     )
#     700     commit_hash = extract_commit_hash(resolved_config_file, commit_hash)
#     701 except EnvironmentError:
#     702     # Raise any environment error raise by `cached_file`. It will have a helpful error message adapted to
#     703     # the original exception.
#
# File ~/pytorch-dir/env/lib/python3.11/site-packages/transformers/utils/hub.py:416, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     414     if resolved_file is not None or not _raise_exceptions_for_gated_repo:
#     415         return resolved_file
# --> 416     raise EnvironmentError(
#     417         "You are trying to access a gated repo.\nMake sure to have access to it at "
#     418         f"https://huggingface.co/{path_or_repo_id}.\n{str(e)}"
#     419     ) from e
#     420 except RepositoryNotFoundError as e:
#     421     raise EnvironmentError(
#     422         f"{path_or_repo_id} is not a local folder and is not a valid model identifier "
#     423         "listed on 'https://huggingface.co/models'\nIf this is a private repository, make sure to pass a token "
#     424         "having permission to this repo either by logging in with `huggingface-cli login` or by passing "
#     425         "`token=<your_token>`"
#     426     ) from e
#
# OSError: You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/meta-llama/Meta-Llama-3-8B.
# 401 Client Error. (Request ID: Root=1-66233314-6a220e0060cf264a547d9b4d;2fbf860f-0269-4320-bdb8-2623699eb74b)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Meta-Llama-3-8B/resolve/main/config.json.
# Repo model meta-llama/Meta-Llama-3-8B is gated. You must be authenticated to access it.

# %%
dataset_name = "mlabonne/orpo-dpo-mix-40k"
dataset = load_dataset(dataset_name, split="all")
dataset = dataset.shuffle(seed=42).select(range(10))

# %%
def format_chat_template(row):
    row["chosen"] = tokenizer.apply_chat_template(row["chosen"], tokenize=False)
    row["rejected"] = tokenizer.apply_chat_template(row["rejected"], tokenize=False)
    return row

dataset = dataset.map(
    format_chat_template,
    num_proc= os.cpu_count(),
)
dataset = dataset.train_test_split(test_size=0.01)
